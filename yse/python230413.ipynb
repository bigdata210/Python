# %% [markdown]
# <a href="https://colab.research.google.com/github/bigdata210/Python/blob/main/yse/python230413.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 라이브러리 불러오기
# - 공식 홈페이지: https://pandas.pydata.org/

# %%
# pandas 버전 확인
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %% [markdown]
# # 구글 드라이브 연동

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 사용자 정의 함수
# - docstring
#   + 모듈, 함수, 클래스 또는 메소드 정의의 첫 번째 명령문으로 발생하는 문자열 리터럴

# %%
def hello():
  """이 함수는 'Hello World!'를 출력한다!"""
  print("Hello World!")

hello()
# Out:
# Hello World!

# %%
help(hello)
# Out:
# Help on function hello in module __main__:
#
# hello()
#     이 함수는 'Hello World!'를 출력한다!

# %%
def hello(name):
  print("안녕!", name)

# %%
hello("Lee")
# Out:
# 안녕! Lee

# %%
hello(123)
# 숫자이지만 name이 가능
# -> 조건문 사용해준다.
# Out:
# 안녕! 123

# %%
# 숫자가 나오게 되면 에러가 뜨도록 만듦.
# default값이 None(함수가 반환하는 값이 없다.)
# python pep8 참고! 
def hello(name: str) -> None:
  if not isinstance(name, str):
    raise TypeError("Name Must be a string!")
  print(f"안녕!, {name}")

hello("Lee")
hello(123)
# Out:
# 안녕!, Lee
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5e39de1ca814> in <cell line: 7>()
#       5
#       6 hello("Lee")
# ----> 7 hello(123)
#
# <ipython-input-15-5e39de1ca814> in hello(name)
#       1 def hello(name: str) -> None:
#       2   if not isinstance(name, str):
# ----> 3     raise TypeError("Name Must be a string!")
#       4   print(f"안녕!, {name}")
#       5
#
# TypeError: Name Must be a string!

# %%
# 원소가 3개만 들어갈 수 있는 덧셈 함수
def add(a, b, c):
  return a + b + c

print(add(1, 2, 3))
print(add(1,2))
# Out:
# 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-895510d3a037> in <cell line: 5>()
#       3
#       4 print(add(1, 2, 3))
# ----> 5 print(add(1,2))
#       6 print(add(1,2,0))
#
# TypeError: add() missing 1 required positional argument: 'c'

# %%
print(add(1,2,0))
print(add(1,2,3,0))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-0c7f5b1dde64> in <cell line: 2>()
#       1 print(add(1,2,0))
# ----> 2 print(add(1,2,3,0))
#
# TypeError: add() takes 3 positional arguments but 4 were given

# %%
# 원소의 갯수가 상관없는 덧셈 함수
def add(*args):
  print(args, type(args))

add(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5) <class 'tuple'>

# %%
def add(*args):
  addition = 0
  for number in args:
    addition += number
  return addition

print(add(1,2))
print(add(1,2,3))
print(add(1,2,3,4))
# Out:
# 3
# 6
# 10

# %%
# **kwargs : 머신러닝 클래스, 하이퍼파라미터 튜닝할 때 사용 
#            (입력값이 dictionary를 기본값으로 받음.)

def temp(**kwargs):   # **kwargs : dictionary 형태로 받음.
  for key, value in kwargs.items():
    print(key, value)

temp(name="hanyoung", age=30, city="Busan")
# Out:
# name hanyoung
# age 30
# city Busan

# %% [markdown]
# # csv 파일 불러오기

# %%
DATA_PATH ='/content/drive/MyDrive/2023/연세IT미래교육원/data/'
print(DATA_PATH)
# Out:
# /content/drive/MyDrive/2023/연세IT미래교육원/data/

# %%
juice = pd.read_csv(DATA_PATH + 'Lemonade2016.csv')
juice.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  7/1/2016     Park     97      67           70      90.0   0.25
# 1  7/2/2016     Park     98      67           72      90.0   0.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25
# 3  7/4/2016    Beach    134      99           76      98.0   0.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25

# %%
juice.tail()
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 27  7/27/2016     Park    104      68           80      99.0   0.35
# 28  7/28/2016     Park     96      63           82      90.0   0.35
# 29  7/29/2016     Park    100      66           81      95.0   0.35
# 30  7/30/2016    Beach     88      57           82      81.0   0.35
# 31  7/31/2016    Beach     76      47           82      68.0   0.35

# %% [markdown]
# - pandas.DataFrame.info() 설명
#   + 참고: https://github.com/pandas-dev/pandas
#   + DataFrame.info(verbose=None, buf=None, max_cols=None, memory_usage=None, show_counts=None) <br/>

# %%
juice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         31 non-null     object
#  1   Location     32 non-null     object
#  2   Lemon        32 non-null     int64
#  3   Orange       32 non-null     int64
#  4   Temperature  32 non-null     int64
#  5   Leaflets     31 non-null     float64
#  6   Price        32 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
type(juice)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - Descriptive Statistics
# - 기술통계량을 확인할 수 있음

# %%
juice.describe()  # 데이터 분포 파악
# Out:
#             Lemon      Orange  Temperature    Leaflets      Price
# count   32.000000   32.000000    32.000000   31.000000  32.000000
# mean   116.156250   80.000000    78.968750  108.548387   0.354688
# std     25.823357   21.863211     4.067847   20.117718   0.113137
# min     71.000000   42.000000    70.000000   68.000000   0.250000
# 25%     98.000000   66.750000    77.000000   90.000000   0.250000
# 50%    113.500000   76.500000    80.500000  108.000000   0.350000
# 75%    131.750000   95.000000    82.000000  124.000000   0.500000
# max    176.000000  129.000000    84.000000  158.000000   0.500000

# %%
juice['Price'].value_counts()
# Out:
# 0.25    15
# 0.50    11
# 0.35     6
# Name: Price, dtype: int64

# %%
juice['Location'].value_counts()
# Out:
# Beach    17
# Park     15
# Name: Location, dtype: int64

# %%
type(juice['Location'].value_counts())
# type이 DateFrame에서 Series로 변경된 것을 확인할 수 있다.
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## column 추가, 삭제
# - sold, sale 추가
# - sold, sale 삭제

# %%
# 새로운 데이터 추가 가능
juice['Sold']= juice['Lemon'] + juice['Orange']
juice.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold
# 0  7/1/2016     Park     97      67           70      90.0   0.25   164
# 1  7/2/2016     Park     98      67           72      90.0   0.25   165
# 2  7/3/2016     Park    110      77           71     104.0   0.25   187
# 3  7/4/2016    Beach    134      99           76      98.0   0.25   233
# 4  7/5/2016    Beach    159     118           78     135.0   0.25   277

# %%
juice['Sale'] = juice['Sold'] * juice['Price']
juice.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold   Sale
# 0  7/1/2016     Park     97      67           70      90.0   0.25   164  41.00
# 1  7/2/2016     Park     98      67           72      90.0   0.25   165  41.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25   187  46.75
# 3  7/4/2016    Beach    134      99           76      98.0   0.25   233  58.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25   277  69.25

# %%
# juice data 복사
df = juice.copy()
df
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold  \
# 0    7/1/2016     Park     97      67           70      90.0   0.25   164
# 1    7/2/2016     Park     98      67           72      90.0   0.25   165
# 2    7/3/2016     Park    110      77           71     104.0   0.25   187
# 3    7/4/2016    Beach    134      99           76      98.0   0.25   233
# 4    7/5/2016    Beach    159     118           78     135.0   0.25   277
# 5    7/6/2016    Beach    103      69           82      90.0   0.25   172
# 6    7/6/2016    Beach    103      69           82      90.0   0.25   172
# 7    7/7/2016    Beach    143     101           81     135.0   0.25   244
# 8         NaN    Beach    123      86           82     113.0   0.25   209
# 9    7/9/2016    Beach    134      95           80     126.0   0.25   229
# 10  7/10/2016    Beach    140      98           82     131.0   0.25   238
# 11  7/11/2016    Beach    162     120           83     135.0   0.25   282
# ...

# %%
# 열 지우기
# df = df.drop('Sold', axis = 1)
# df = df.drop('Sale', axis = 1)

# 여러 열을 한꺼번에 제거하고 싶을 경우 
# cols로 묶어서 제거한다.
cols = ['Sold', 'Sale']
df = df.drop(cols, axis =1)
df.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 0  7/1/2016     Park     97      67           70      90.0   0.25
# 1  7/2/2016     Park     98      67           72      90.0   0.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25
# 3  7/4/2016    Beach    134      99           76      98.0   0.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25

# %%
# 행 지우기
df = df.drop(3, axis = 0)

# 여러 행을 한꺼번에 제거하고 싶을 경우
df = df.drop([0,2,4], axis = 0)
df.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price
# 1  7/2/2016     Park     98      67           72      90.0   0.25
# 5  7/6/2016    Beach    103      69           82      90.0   0.25
# 6  7/6/2016    Beach    103      69           82      90.0   0.25
# 7  7/7/2016    Beach    143     101           81     135.0   0.25
# 8       NaN    Beach    123      86           82     113.0   0.25

# %% [markdown]
# ## 행 추출

# %%
juice.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold   Sale
# 0  7/1/2016     Park     97      67           70      90.0   0.25   164  41.00
# 1  7/2/2016     Park     98      67           72      90.0   0.25   165  41.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25   187  46.75
# 3  7/4/2016    Beach    134      99           76      98.0   0.25   233  58.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25   277  69.25

# %%
# Location에서 Beach만 추출
result = juice[juice['Location'] == 'Beach' ]
result.head(1)
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold   Sale
# 3  7/4/2016    Beach    134      99           76      98.0   0.25   233  58.25

# %%
result = juice[juice['Leaflets'] <=98]
result
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold  \
# 0    7/1/2016     Park     97      67           70      90.0   0.25   164
# 1    7/2/2016     Park     98      67           72      90.0   0.25   165
# 3    7/4/2016    Beach    134      99           76      98.0   0.25   233
# 5    7/6/2016    Beach    103      69           82      90.0   0.25   172
# 6    7/6/2016    Beach    103      69           82      90.0   0.25   172
# 16  7/16/2016    Beach     81      50           74      90.0   0.50   131
# 21  7/21/2016     Park     83      50           77      90.0   0.50   133
# 28  7/28/2016     Park     96      63           82      90.0   0.35   159
# 29  7/29/2016     Park    100      66           81      95.0   0.35   166
# 30  7/30/2016    Beach     88      57           82      81.0   0.35   145
# 31  7/31/2016    Beach     76      47           82      68.0   0.35   123
#
#      Sale
# 0   41.00
# 1   41.25
# 3   58.25
# 5   43.00
# 6   43.00
# ...

# %%
result = juice[juice['Sold'] >= 200]
result
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold  \
# 3    7/4/2016    Beach    134      99           76      98.0   0.25   233
# 4    7/5/2016    Beach    159     118           78     135.0   0.25   277
# 7    7/7/2016    Beach    143     101           81     135.0   0.25   244
# 8         NaN    Beach    123      86           82     113.0   0.25   209
# 9    7/9/2016    Beach    134      95           80     126.0   0.25   229
# 10  7/10/2016    Beach    140      98           82     131.0   0.25   238
# 11  7/11/2016    Beach    162     120           83     135.0   0.25   282
# 12  7/12/2016    Beach    130      95           84      99.0   0.25   225
# 14  7/14/2016    Beach    122      85           78     113.0   0.25   207
# 18  7/18/2016     Park    131      92           81     122.0   0.50   223
# 19  7/19/2016     Park    122      85           78     113.0   0.50   207
# 23  7/23/2016     Park    120      82           81     117.0   0.50   202
# ...

# %% [markdown]
# ## iloc & loc
# - loc가 중요하다!

# %%
#iloc (True, False값에서 True인 값만 나옴.)
juice.head()
# Out:
#        Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold   Sale
# 0  7/1/2016     Park     97      67           70      90.0   0.25   164  41.00
# 1  7/2/2016     Park     98      67           72      90.0   0.25   165  41.25
# 2  7/3/2016     Park    110      77           71     104.0   0.25   187  46.75
# 3  7/4/2016    Beach    134      99           76      98.0   0.25   233  58.25
# 4  7/5/2016    Beach    159     118           78     135.0   0.25   277  69.25

# %%
# 인덱스 2까지, 열 2까지
juice.iloc[0:3, 0:2]   # i = index
# Out:
#         Date Location
# 0 2016-07-01     Park
# 1 2016-07-02     Park
# 2 2016-07-03     Park

# %%
# label 2까지
juice.loc[0:2, ['Date', 'Location']]  # 인덱스(x)
# Out:
#        Date Location
# 0  7/1/2016     Park
# 1  7/2/2016     Park
# 2  7/3/2016     Park

# %%
juice.loc[juice['Temperature'] == 82, ['Date','Location','Temperature']]
# Out:
#          Date Location  Temperature
# 5    7/6/2016    Beach           82
# 6    7/6/2016    Beach           82
# 8         NaN    Beach           82
# 10  7/10/2016    Beach           82
# 24  7/24/2016     Park           82
# 28  7/28/2016     Park           82
# 30  7/30/2016    Beach           82
# 31  7/31/2016    Beach           82

# %%
# iloc는 조건식으로 사용 불가
# 이유? iloc는 True인 값만 나오게 하므로 조건식으로 안됨.
juice.iloc[juice['Temperature'] == 82, 0:2]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-190-9800315ce4c8> in <cell line: 3>()
#       1 # iloc는 조건식으로 사용 불가
#       2 # 이유? iloc는 True인 값만 나오게 하므로 조건식으로 안됨.
# ----> 3 juice.iloc[juice['Temperature'] == 82, 0:2]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
# ...

# %% [markdown]
# ## 다중 조건식
# - data.loc[() & () | (), 열]

# %%
juice.loc[(juice['Temperature'] == 82) & 
          (juice['Location'] == "Park") &
          (juice['Date'] == "7/24/2016"), ['Date','Location']]
# Out:
#          Date Location
# 24  7/24/2016     Park

# %%
juice.loc[(juice['Temperature'] == 82) & 
          (juice['Location'] == "Park") &
          (juice['Date'] == "7/24/2016"), :]
# Out:
#          Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold  \
# 24  7/24/2016     Park    121      82           82     117.0    0.5   203
#
#      Sale
# 24  101.5

# %%
# 컬럼의 이름값을 변경 
result = juice.rename(columns={"Orange":"apple","Price":"PPP"})
result.head(1)
# Out:
#        Date Location  Lemon  apple  Temperature  Leaflets   PPP  Sold  Sale
# 0  7/1/2016     Park     97     67           70      90.0  0.25   164  41.0

# %%
juice.head()
juice['Location'].value_counts()
# Out:
# Beach    17
# Park     15
# Name: Location, dtype: int64

# %%
juice['Location'].value_counts(normalize=True)  
# normalize : 비율로 나옴
# Out:
# Beach    0.53125
# Park     0.46875
# Name: Location, dtype: float64

# %%
import numpy as np
result = np.round(juice['Location'].value_counts(normalize=True),2)
result
# Out:
# Beach    0.53
# Park     0.47
# Name: Location, dtype: float64

# %%
# 시계열 데이터
#형식을 변환해준다 메소드를 활용하기 위해서
juice['Date'] = pd.to_datetime(juice['Date'])
juice['year'] = juice['Date'].dt.year
juice['month'] = juice['Date'].dt.month
juice['day'] = juice['Date'].dt.day
juice.head(1)
# Out:
#         Date Location  Lemon  Orange  Temperature  Leaflets  Price  Sold  \
# 0 2016-07-01     Park     97      67           70      90.0   0.25   164
#
#    Sale    year  month  day
# 0  41.0  2016.0    7.0  1.0

# %%
juice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         31 non-null     datetime64[ns]
#  1   Location     32 non-null     object
#  2   Lemon        32 non-null     int64
#  3   Orange       32 non-null     int64
#  4   Temperature  32 non-null     int64
#  5   Leaflets     31 non-null     float64
#  6   Price        32 non-null     float64
#  7   Sold         32 non-null     int64
#  8   Sale         32 non-null     float64
#  9   year         31 non-null     float64
#  10  month        31 non-null     float64
#  11  day          31 non-null     float64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(1)
# memory usage: 3.1+ KB

# %%
juice['Date'].max() - juice['Date'].min()
# Out:
# Timedelta('30 days 00:00:00')

# %%
# shift()
trans_df = juice[['Date','Price']].copy()
trans_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
trans_df['shifted_1'] = trans_df['Price'].shift(1, fill_value=0).astype(float)
trans_df['shifted_2'] = trans_df['Price'].shift(2, fill_value=0).astype(float)
trans_df.head()

trans_df['차이값'] = trans_df['Price'] - trans_df['shifted_1']
trans_df.head()
# Out:
#         Date  Price  shifted_1  shifted_2   차이값
# 0 2016-07-01   0.25       0.00       0.00  0.25
# 1 2016-07-02   0.25       0.25       0.00  0.00
# 2 2016-07-03   0.25       0.25       0.25  0.00
# 3 2016-07-04   0.25       0.25       0.25  0.00
# 4 2016-07-05   0.25       0.25       0.25  0.00

# %%
# 0000년 00월 00일
trans_df['한글날짜'] = trans_df['Date'].dt.strftime("%Y년 %m월 %d일")
trans_df.head()
# Out:
#         Date  Price  shifted_1  shifted_2   차이값           한글날짜
# 0 2016-07-01   0.25       0.00       0.00  0.25  2016년 07월 01일
# 1 2016-07-02   0.25       0.25       0.00  0.00  2016년 07월 02일
# 2 2016-07-03   0.25       0.25       0.25  0.00  2016년 07월 03일
# 3 2016-07-04   0.25       0.25       0.25  0.00  2016년 07월 04일
# 4 2016-07-05   0.25       0.25       0.25  0.00  2016년 07월 05일

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       31 non-null     datetime64[ns]
#  1   Price      32 non-null     float64
#  2   shifted_1  32 non-null     float64
#  3   shifted_2  32 non-null     float64
#  4   차이값        32 non-null     float64
#  5   한글날짜       31 non-null     object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 1.6+ KB

# %% [markdown]
# ### boston 데이터
# - boston 데이터 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

print('pandas version', pd.__version__)
# Out:
# pandas version 1.5.3

# %%
# boston.csv 파일 불러오기
DATA_PATH='/content/drive/MyDrive/2023/연세IT미래교육원/data/'
print(DATA_PATH)
# Out:
# /content/drive/MyDrive/2023/연세IT미래교육원/data/

# %%
df_boston = pd.read_csv(DATA_PATH + 'boston.csv')
df_boston.head(1)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0     15.3
#
#        B  LSTAT  target
# 0  396.9   4.98    24.0

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  target   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# CRIM, ZN, INDUS 컬럼 추출
cols = ['CRIM', 'ZN', 'INDUS']
result = df_boston[cols]
result = df_boston.loc[:,cols]
result
# Out:
#         CRIM    ZN  INDUS
# 0    0.00632  18.0   2.31
# 1    0.02731   0.0   7.07
# 2    0.02729   0.0   7.07
# 3    0.03237   0.0   2.18
# 4    0.06905   0.0   2.18
# ..       ...   ...    ...
# 501  0.06263   0.0  11.93
# 502  0.04527   0.0  11.93
# 503  0.06076   0.0  11.93
# 504  0.10959   0.0  11.93
# 505  0.04741   0.0  11.93
#
# [506 rows x 3 columns]

# %%
# 행 추출, ZN = 18.0 인 값만 조회, 컬럼은 CRIM, ZN, INDUS 추출
result = df_boston.loc[df_boston['ZN'] == 18.0, ['CRIM','ZN', 'INDUS']] 
result = df_boston.loc[df_boston['ZN'] == 18.0, cols]
result
# Out:
#       CRIM    ZN  INDUS
# 0  0.00632  18.0   2.31

# %%
## 다중조건식
cols = ['CRIM', 'ZN', 'target']
#result = data.loc[(조건식1)& (조건식2), cols]

# CRIM이 1보다 작고, target이 24 이상인 값만 조회
# 단계별로 확인
result= df_boston.loc[(df_boston['CRIM'] < 1) &
                       (df_boston['target'] >= 24), cols]    
result
# Out:
#         CRIM    ZN  target
# 0    0.00632  18.0    24.0
# 2    0.02729   0.0    34.7
# 3    0.03237   0.0    33.4
# 4    0.06905   0.0    36.2
# 5    0.02985   0.0    28.7
# ..       ...   ...     ...
# 348  0.01501  80.0    24.5
# 349  0.02899  40.0    26.6
# 351  0.07950  60.0    24.1
# 353  0.01709  90.0    30.1
# 494  0.27957   0.0    24.5
#
# [138 rows x 3 columns]

# %%
# CRIM이 1보다 작거나, target이 24 이상인 값만 조회
result = df_boston.loc[(df_boston['CRIM'] <= 1) |
                        (df_boston['target'] >= 24), cols]
result
# Out:
#         CRIM    ZN  target
# 0    0.00632  18.0    24.0
# 1    0.02731   0.0    21.6
# 2    0.02729   0.0    34.7
# 3    0.03237   0.0    33.4
# 4    0.06905   0.0    36.2
# ..       ...   ...     ...
# 501  0.06263   0.0    22.4
# 502  0.04527   0.0    20.6
# 503  0.06076   0.0    23.9
# 504  0.10959   0.0    22.0
# 505  0.04741   0.0    11.9
#
# [351 rows x 3 columns]

# %%
# rename 컬럼의 이름값 변경 -> dictionary 
# ZN -> landZone으로 변경
result = df_boston.rename(columns={'ZN': 'landZone'})
result.head(1)
# Out:
#       CRIM  landZone  INDUS  CHAS    NOX     RM   AGE   DIS  RAD    TAX  \
# 0  0.00632      18.0   2.31   0.0  0.538  6.575  65.2  4.09  1.0  296.0
#
#    PTRATIO      B  LSTAT  target
# 0     15.3  396.9   4.98    24.0

# %%
# 컬럼의 이름값을 여러개 변경
result = df_boston.rename(columns={"DDD":"ABC", "TAX":"DEF"})
result.head(1)

tempDict = {
    'ZN' : 'landZone',
    'CRIM': 'A',
    'CHAS' : 'BA',
    'TAX' : 'C'
}
result = df_boston.rename(columns = tempDict)
result.head(1)
# Out:
#          A  landZone  INDUS   BA    NOX     RM   AGE   DIS  RAD      C  \
# 0  0.00632      18.0   2.31  0.0  0.538  6.575  65.2  4.09  1.0  296.0
#
#    PTRATIO      B  LSTAT  target
# 0     15.3  396.9   4.98    24.0

# %%
# value_counts()
df_boston['RAD'].value_counts()
# Out:
# 24.0    132
# 5.0     115
# 4.0     110
# 3.0      38
# 6.0      26
# 2.0      24
# 8.0      24
# 1.0      20
# 7.0      17
# Name: RAD, dtype: int64

# %%
df_boston['RAD'].value_counts(normalize=True)  # normalize : 비율로 나옴
# Out:
# 24.0    0.260870
# 5.0     0.227273
# 4.0     0.217391
# 3.0     0.075099
# 6.0     0.051383
# 2.0     0.047431
# 8.0     0.047431
# 1.0     0.039526
# 7.0     0.033597
# Name: RAD, dtype: float64

# %%
import numpy as np
result = np.round(df_boston['RAD'].value_counts(normalize=True), 2)
result
# Out:
# 24.0    0.26
# 5.0     0.23
# 4.0     0.22
# 3.0     0.08
# 6.0     0.05
# 2.0     0.05
# 8.0     0.05
# 1.0     0.04
# 7.0     0.03
# Name: RAD, dtype: float64

# %% [markdown]
# ## 시계열 데이터 다루기
# - Timestamp
# - 참고 : https://pandas.pydata.org/docs/reference/api/pandas.Timestamp.html
#
# - Datetimelndex
# - 참고 : https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html

# %%
date_string = "2023-04-13"
datetime_obj = pd.to_datetime(date_string)
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2023-04-13 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
date_list = ['2023-04-12', '2023-04-13']
datetime_obj_list = pd.to_datetime(date_list)
print(datetime_obj_list)
print(type(datetime_obj_list))

# type이 변경되었다. timestamps -> datetimelndex
# Out:
# DatetimeIndex(['2023-04-12', '2023-04-13'], dtype='datetime64[ns]', freq=None)
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %% [markdown]
# ### sales 데이터
# - raw_sales.csv 파일 불러오기

# %%
sales = pd.read_csv(DATA_PATH + "raw_sales.csv")
sales.head(1)
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  object
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# - 형식을 변환해줘야 한다.
#   + why? 시계열 데이터를 사용하기 위해
#   + 메소드를 활용하기 위해

# %%
sales['datesold'] = pd.to_datetime(sales['datesold'])
sales['year'] = sales['datesold'].dt.year  
sales['month'] = sales['datesold'].dt.month
sales['day'] = sales['datesold'].dt.day
sales.head(1)
# Out:
#     datesold  postcode   price propertyType  bedrooms  year  month  day
# 0 2007-02-07      2607  525000        house         4  2007      2    7

# %%
sales.info()
# datesold가 datetime으로 변환된 것을 확인할 수 있다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  datetime64[ns]
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
#  5   year          29580 non-null  int64
#  6   month         29580 non-null  int64
#  7   day           29580 non-null  int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 1.8+ MB

# %%
# 처음 data와 마지막 data의 기간
sales['datesold'].max() - sales['datesold'].min()
# Out:
# Timedelta('4553 days 00:00:00')

# %% [markdown]
# - shift()

# %%
temp_df = sales[['datesold','price']].copy()
temp_df.head()
# Out:
#     datesold   price
# 0 2007-02-07  525000
# 1 2007-02-27  290000
# 2 2007-03-07  328000
# 3 2007-03-09  380000
# 4 2007-03-21  310000

# %%
# 날짜별 판매량, 전주 대비 등의 값을 비교하여 볼 수 있다.
temp_df['shifted_v1'] = temp_df['price'].shift(1, fill_value=0).astype(int)  
# price를 1칸씩 밀고 값을 0으로 채운다.
# astype(int) : 나오는 값에 상관없이 int로 변경한다.
temp_df['shifted_v2'] = temp_df['price'].shift(2, fill_value=0).astype(int) 

temp_df['차이값'] = temp_df['price'] - temp_df['shifted_v1']
temp_df.head()
# Out:
#     datesold   price  shifted_v1  shifted_v2     차이값
# 0 2007-02-07  525000           0           0  525000
# 1 2007-02-27  290000      525000           0 -235000
# 2 2007-03-07  328000      290000      525000   38000
# 3 2007-03-09  380000      328000      290000   52000
# 4 2007-03-21  310000      380000      328000  -70000

# %%
# 0000년 00월 00일 
temp_df['한글날짜'] = temp_df['datesold'].dt.strftime('%Y년 %m월 %d일')
temp_df.head()
# Out:
#     datesold   price  shifted_v1  shifted_v2     차이값           한글날짜
# 0 2007-02-07  525000           0           0  525000  2007년 02월 07일
# 1 2007-02-27  290000      525000           0 -235000  2007년 02월 27일
# 2 2007-03-07  328000      290000      525000   38000  2007년 03월 07일
# 3 2007-03-09  380000      328000      290000   52000  2007년 03월 09일
# 4 2007-03-21  310000      380000      328000  -70000  2007년 03월 21일

# %%
temp_df.info()
# 한글날짜 type : object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datesold    29580 non-null  datetime64[ns]
#  1   price       29580 non-null  int64
#  2   shifted_v1  29580 non-null  int64
#  3   shifted_v2  29580 non-null  int64
#  4   차이값         29580 non-null  int64
#  5   한글날짜        29580 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 1.4+ MB
